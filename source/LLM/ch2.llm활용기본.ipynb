# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# ## ch2. LLM활용의 기본 개념(Ollama)
# -1. LLM을 활용하여 답변 생성하기
# -1) Ollama 이용한 로컬 LLM 이용
# -성능은 GPT, Claude 같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# -ollama.com 다운로드 -> 설치 -> 모델 pull
# -ollama pull deepseek-r1:1.5b (window키+R => powershell

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke('what is the capital of korea')
result
# Out:
# AIMessage(content='<think>\n\n</think>\n\nThe capital of Korea, which is South Korea, is Dongdaemun City. It was officially recognized as the capital on December 19, 2023.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-06-26T01:50:51.6894997Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4719548500, 'load_duration': 2261357000, 'prompt_eval_count': 10, 'prompt_eval_duration': 268321800, 'eval_count': 41, 'eval_duration': 2183520900, 'model_name': 'deepseek-r1:1.5b'}, id='run--bc6f2219-7e17-4566-8fc4-e1eb86efbf9f-0', usage_metadata={'input_tokens': 10, 'output_tokens': 41, 'total_tokens': 51})

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of Korea?")
result
# Out:
# AIMessage(content="The capital of South Korea is Seoul. However, it's worth noting that there are also two other cities that serve as special administrative regions: Pyongyang, North Korea (the capital of North Korea), and Pjöngjang, North Korea (the administrative center of the Democratic People's Republic of Korea).", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T02:23:29.8546682Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6864141700, 'load_duration': 2438647700, 'prompt_eval_count': 32, 'prompt_eval_duration': 668149300, 'eval_count': 62, 'eval_duration': 3756789200, 'model_name': 'llama3.2:1b'}, id='run--dfbb0311-44e7-46ee-89d1-bd75b360043d-0', usage_metadata={'input_tokens': 32, 'output_tokens': 62, 'total_tokens': 94})

# %% [markdown]
# ## open ai 활용

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano")
llm.invoke('what is the capital of korea? answer me in korean')
# Out:
# AIMessage(content='한국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 18, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_38343a2f8f', 'id': 'chatcmpl-BmBeTjvRv6JiVBLvZq7yXLwhU8oUd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--fc2f180c-3828-46db-92dc-c09f6a87a758-0', usage_metadata={'input_tokens': 18, 'output_tokens': 7, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import AzureChatOpenAI
llm = AzureChatOpenAI(model="gpt-4.1-nano")
llm.invoke('what is the capital of korea?')
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 from langchain_openai import AzureChatOpenAI
# ----> 2 llm = AzureChatOpenAI(model="gpt-4.1-nano")
#       3 llm.invoke('what is the capital of korea?')
#
# File ~\anaconda3\envs\llm\Lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
# File ~\anaconda3\envs\llm\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for AzureChatOpenAI
#   Value error, Must provide either the `api_version` argument or the `OPENAI_API_VERSION` environment variable [type=value_error, input_value={'model': 'gpt-4.1-nano', 'model_kwargs': {}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error

# %% [markdown]
# # 2. 랭체인 프롬프트

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
#llm.invoke(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 from langchain_ollama import ChatOllama
#       2 llm = ChatOllama(model="llama3.2:1b")
# ----> 3 llm.invoke(0)
#
# File ~\anaconda3\envs\llm\Lib\site-packages\langchain_core\language_models\chat_models.py:373, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
#     372         self.generate_prompt(
# --> 373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~\anaconda3\envs\llm\Lib\site-packages\langchain_core\language_models\chat_models.py:358, in BaseChatModel._convert_input(self, model_input)
#     353     return ChatPromptValue(messages=convert_to_messages(model_input))
#     354 msg = (
#     355     f"Invalid input type {type(model_input)}. "
#     356     "Must be a PromptValue, str, or list of BaseMessages."
#     357 )
# --> 358 raise ValueError(msg)
#
# ValueError: Invalid input type <class 'int'>. Must be a PromptValue, str, or list of BaseMessages.

# %% [markdown]
# ## 기본 프롬프트 템플렛 사용

# %%
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llam3.2:1b")
prompt_template = promptTemplate(
    template="what is the captial of {country}", #{} 안의 값을 새로운 값으로 할당 가능)
    input_variable = ["country"])
prompt = prompt_template.invoke({'country':'korea'})
print(prompt)
llm.invoke(prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 from langchain_core.prompts import PromptTemplate
#       2 llm = ChatOllama(model="llam3.2:1b")
# ----> 3 prompt_template = promptTemplate(
#       4     template="what is the captial of {country}", #{} 안의 값을 새로운 값으로 할당 가능)
#       5     input_variable = ["country"])
#       6 prompt = prompt_template.invoke({'country':'korea'})
#       7 print(prompt)
#
# NameError: name 'promptTemplate' is not defined

# %% [markdown]
# ## 2) 메세지 기반 프롬프트 작성
# - BaseMessage 리스트
# - BaseMessafe 상속받은 클래스 : AIMessafe, HummanMesssafe, SystemMessafe, ToolMessage

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of France?")
]
llm.invoke(message_list)
# Out:
# AIMessage(content="The capital of Korea (South Korea) is Seoul. \n\nHowever, if you are referring to North Korea, its official name is Democratic People's Republic of Korea (DPRK), and its capital is Pyongyang.\n\nBut if you meant Italy, which I already corrected to Rome earlier, it has two capitals: Rome (the country) and Vatican City (an independent city-state within Rome).", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T06:13:23.8796237Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8726089700, 'load_duration': 2077536500, 'prompt_eval_count': 86, 'prompt_eval_duration': 1587141900, 'eval_count': 80, 'eval_duration': 5058992900, 'model_name': 'llama3.2:1b'}, id='run--550d03b6-585d-4da5-bb76-be0f77ae1c0d-0', usage_metadata={'input_tokens': 86, 'output_tokens': 80, 'total_tokens': 166})

# %%
# BaseMessage list로 하면 렝체인화X, ChatPromptTemplateX
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of {country}?")
]
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate.from_messages(message_list)
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Seoul.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of {country}?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## chat promptTemplate 사용

# %%
# 위의 baseMessage 를 수정
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "You ara a helpful assistant!"),
    ("human", "what is the capital of {country}?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print(prompt)
result = llm.invoke(prompt)
result.content
# Out:
# 어느 나라 수도가 궁금하세요?df
# messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='what is the capital of df?', additional_kwargs={}, response_metadata={})]
# 'I\'m not aware of any country called "DF". Could you be referring to a different location or country? If you could provide more context or information, I\'d be happy to try and help.'

# %% [markdown]
# # 3. 답변의 형식을 컨트롤 하기
# - invoke 실행 결과는 aiMessafe() -> String 이나 json, 객체 : outputParser이용

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
prompt_template = PromptTemplate(
    template = "what is the capital of {country}. Return the name of the city only",
    input_varibles = ["country"])

# 프롬프트 템플렛에 값 주입
prompt = prompt_template.invoke({"country":"korea"})
print("프롬프트",prompt)
result = llm.invoke(prompt)
print('llm 결과:', type(result))
# 문자열 풀력 파셔를 이용해서 llm ㅇㅇ답을 단순 문자열 변환
output_parser = StrOutputParser()
print(output_parser.invoke(result))
# Out:
# 프롬프트 text='what is the capital of korea. Return the name of the city only'
# llm 결과: <class 'langchain_core.messages.ai.AIMessage'>
# Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"korea"})))
# Out:
# 'Seoul'

# %%
# PromptTemplate(변수설정) => ChatPromptTemplate(변수설정, system과 모법답안 지정)
llm = ChatOllama(model="llama3.2:1b")

chat_prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant with expertise in South Korea."),
    ("human", "What is the capital of {country}? Return the name if the city only.")
])

output_parser = StrOutputParser()

output_parser.invoke(llm.invoke(chat_prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# # 2)응답 타입 확인
# json()으로 응답하기를 원하지만, 우선 어떤 형식으로 반환되는 확인
# {"name":"홍","age":22}(json) /{'name':'홍','age':22}(dict)

# %%
from langchain_core.output_parsers import JsonOutputParser
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
prompt = country_detail_prompt.invoke({"country":"Korea"})
print(type(prompt), prompt)
# Json output 파서
output_parser = JsonOutputParser()
ai_message = llm.invoke(prompt)
print(type(prompt), ai_message)
json_result = output_parser.invoke(ai_message)
print(type(json_result), json_result)
# Out:
# <class 'langchain_core.prompt_values.StringPromptValue'>

# %% [markdown]
# # 구조화된 출력 사용
# - Pydantic 모델을 사용하여 LLM 출력을 구조화된 형식으로 받기
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
from pydantic import BaseModel, Field
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name=name
        self.is_active = is_active
user = User(1, "홍길동")
print(user)
# Out:
# <__main__.User object at 0x000002909DE21A90>

# %%
class User(BaseModel):
    id:int
    name:str
    is_activate:bool=True
user = User(id="1", name="홍길동")
print(user)
# Out:
# id=1 name='홍길동' is_activate=True

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    id:int = Field(gt=0)
    name:str = Field(min_length=2)
    is_activate:bool=Field(default=True, )
user = User(id='1', name='홍길동')
print(user)
# Out:
# id=1 name='홍길동' is_activate=True

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
class CountryDetail(BaseModel): # description: 더 정확한 출력 유도
    capital:str    = Field(description="the capital of the country")
    population:int = Field(description="the population of the country")
    language:str   = Field(description="the language of the country")
    currency:str   = Field(description="the currency of the country")
# 출력 형식 파서 + LLM
structedllm = llm.with_structured_output(CountryDetail)

# output_parser = JsonOutputParser()
# output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":"Korea"})))

# %%
# 프롬프트템플릿 -> llm -> 출력파서를 연결하는 체인 생성
capital_chain = prompt_template | llm | output_parser
# 생성된 체인 invoke
capital_chain.invoke({"country":"Korea"})
# Out:
# 'Seoul'

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b", 
                 temperature=0) # 일관된 답변
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 복합체인 구성
# - 여러단계의 추론이 필요한 경우 (체인 연결)

# %%
# 나라 설명 -> 나라명 
from langchain_core.prompts import PromptTemplate
country_prompt = PromptTemplate(
    template = """Guess the name of the country based on the following information:
    {information}
    Return the name of the country only""",
    input_variables=['information'])

output_parser.invoke(llm.invoke(country_prompt.invoke({"information":
                                                      "This country is very famous for its wine"})))
# Out:
# 'Italy'

# %%
# 나라명 추측 체인 생성
country_chain = country_prompt | llm | output_parser
country_chain.invoke({"information":"This country is very famous for its wine"})
# Out:
# 'Italy'

# %%
# 나라설명 -> (나라명) -> 그 나라 수도를 출력
final_chain = country_chain | capital_chain
final_chain.invoke({"information":"this This country is very famous for its wine"})
# Out:
# 'Rome'

# %%
final_chain={"country":country_chain | capital_chain}
final_chain.invoke({"information":"this This country is very famous for its wine"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 final_chain={"country":country_chain | capital_chain}
# ----> 2 final_chain.invoke({"information":"this This country is very famous for its wine"})
#
# AttributeError: 'dict' object has no attribute 'invoke'

# %%
from langchain_core.runnables import RunnablePassthrough
final_chain = {"information":RunnablePassthrough()}| \
                {"country":country_chain} | capital_chain
final_chain.invoke("This country is very famous for its wine")
# Out:
# 'Rome'

# %%
# 프롬프트 템플렛에 변수2
# 나라설명 -> 나라명

# %%
from langchain_core.prompts import PromptTemplate
country_prompt = PromptTemplate(
    template = """Guess the name of the country in the {continent} based on the following information:
    {information}
    Return the name of the country only""",
    input_variables=['information','continent'])

country_chain = country_prompt | llm | output_parser
country_chain.invoke({"information":"this This country is very famous for its wine",
                      "continent":"Europe"})
# Out:
# 'Italy.'

# %%
final_chain = {"country" : country_chain} | capital_chain
final_chain.invoke({"information":"this This country is very famous for its wine",
                      "continent":"Europe"})
# Out:
# 'Rome'
