# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\python.exe

# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
plt.rc('font', family = 'Hancom Gothic')

# %%
df_total = pd.read_csv(r"C:\Ai_x\lecNote\FlowCast\Data_Analysis\서울시_시간별_PM_배치_2021_2025.csv", parse_dates=['일시'])
df_total = df_total[df_total['일시']<'2025']
df_total.columns = ['일시','행정구','대여량']

# %%
plt.figure(figsize=(16,9))
plt.plot(df_total['일시'], df_total['대여량'])
# plt.axvline(x=pd.to_datetime('2021-07-01'), color='black')
# plt.axvline(x=pd.to_datetime('2022-07-01'), color='black')
# plt.axvline(x=pd.to_datetime('2023-07-01'), color='black')
# plt.axvline(x=pd.to_datetime('2024-07-01'), color='black')
plt.xlabel('시간', size=15)
plt.ylabel('PM대여량', size=15)
plt.title('시간의 흐름에 따른 PM대여량의 변화 추이', size=20, fontweight='bold')
plt.show()

# %% [markdown]
# <font size=5>위 그림으로 보아 자전거는 월의 변화에 따른 트랜드가 발생하며 이는 기상, 계절과 연관성이 깊으므로 모델 설계의 feature로 사용</font>
# - 한국의 경우, 계절별 기온, 풍속, 습도, 강수의 차이가 발생하므로 일시 데이터와 기상 데이터를 사용하여 계절성 고려 모델 생성

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\admin\anaconda3\lib\site-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: scipy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import sys
print(sys.executable)
import sys
!"{sys.executable}" -m pip install --upgrade statsmodels
# Out:
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\python.exe
# Collecting statsmodels
#   Downloading statsmodels-0.14.5-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels) (1.5.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from python-dateutil>=2.8.1->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.5-cp310-cp310-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.6 MB 11.8 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 11.3 MB/s eta 0:00:00
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.1 statsmodels-0.14.5

# %%
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(df_total['대여량'],
                           model = 'additive',
                           period=90, 
                           )

# %%
# 그래프로 체크
fig, axes = plt.subplots(4,1, figsize = (12,6))
axes[0].plot(result.observed)
axes[0].set_ylabel('관측값')
axes[1].plot(result.trend)
axes[1].set_ylabel('트랜드')
axes[2].plot(result.seasonal)
axes[2].set_ylabel('주기성')
axes[3].plot(result.resid)
axes[3].set_ylabel('잔차')
plt.xlabel('시간흐름')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13984\253488355.py:12: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Prophet을 사용해서 예측하기

# %%
# 1) '일시'와 '대여량' 컬럼만 선택해 복사본 생성
df_prophet = df_total[['일시', '대여량']].copy()

# 2) Prophet이 요구하는 컬럼명으로 변경
df_prophet.columns = ['ds', 'y']

# 3) 확인
print(df_prophet.head())
# Out:
#                    ds   y
# 0 2021-01-01 00:00:00  24
# 1 2021-01-01 01:00:00  24
# 2 2021-01-01 02:00:00  24
# 3 2021-01-01 03:00:00  24
# 4 2021-01-01 04:00:00  24

# %%
# %pip install prophet
# Out:
# Collecting prophet
#   Using cached prophet-1.1.7-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Using cached cmdstanpy-1.2.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (3.7.0)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from prophet) (1.5.3)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.76-py3-none-any.whl.metadata (44 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting importlib_resources (from prophet)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Using cached stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\ml-dl-nlp\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Using cached prophet-1.1.7-py3-none-win_amd64.whl (13.3 MB)
# Downloading holidays-0.76-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 9.2 MB/s eta 0:00:00
# Using cached cmdstanpy-1.2.5-py3-none-any.whl (94 kB)
# Using cached stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Installing collected packages: tqdm, stanio, importlib_resources, holidays, cmdstanpy, prophet
#
#    ------------- -------------------------- 2/6 [importlib_resources]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------- ------------------- 3/6 [holidays]
#    -------------------------- ------------- 4/6 [cmdstanpy]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    --------------------------------- ------ 5/6 [prophet]
#    ---------------------------------------- 6/6 [prophet]
#
# Successfully installed cmdstanpy-1.2.5 holidays-0.76 importlib_resources-6.5.2 prophet-1.1.7 stanio-0.5.1 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\Admin\anaconda3\envs\ml-dl-nlp\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts install_cmdstan.exe and install_cxx_toolchain.exe are installed in 'C:\Users\Admin\anaconda3\envs\ml-dl-nlp\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# 1) Prophet용으로 '일시'와 '대여량'만 골라 새 DataFrame 생성
df_total_prophet = df_total[['일시', '대여량']].copy()

# 2) 컬럼명을 Prophet이 요구하는 'ds', 'y'로 변경
df_total_prophet.columns = ['ds', 'y']

# (선택) DS 컬럼이 datetime 타입인지 확인 및 변환
df_total_prophet['ds'] = pd.to_datetime(df_total_prophet['ds'])

# 3) 확인
print(df_total_prophet.head())
print(df_total_prophet.columns)  # ['ds', 'y'] 여야 합니다.

# 4) 모델 학습
from prophet import Prophet
m = Prophet()
m.fit(df_total_prophet)
# Out:
#                    ds   y
# 0 2021-01-01 00:00:00  24
# 1 2021-01-01 01:00:00  24
# 2 2021-01-01 02:00:00  24
# 3 2021-01-01 03:00:00  24
# 4 2021-01-01 04:00:00  24
# Index(['ds', 'y'], dtype='object')
# 17:01:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:01:45 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
m.plot(forecast)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\prophet\plot.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.tight_layout()
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
f2 = m.plot_components(forecast) # 트랜드와 휴일효과 그래프
# Out:
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\prophet\plot.py:197: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.tight_layout()
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\Admin\anaconda3\envs\ml-dl-nlp\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
