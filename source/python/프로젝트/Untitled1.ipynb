# %%
import pandas as pd

df_busan = pd.read_csv("C:/Users/Admin/Desktop/새 폴더/LOCAL_PEOPLE_DONG_202506.csv")

# %%
df_busan
# Out:
#           기준일ID     시간대구분       행정동코드     총생활인구수  남자0세부터9세생활인구수  \
# 20250601      0  11170690  13016.4691   504.7423       363.9773
# 20250601      0  11260660  12465.4868   402.3057       206.1997
# 20250601      0  11620735  27735.1490   357.5485       181.0755
# 20250601      0  11290640  14738.4304   273.6058       141.1779
# 20250601      0  11215830  24319.6994   969.6121       453.5985
# ...         ...       ...         ...        ...            ...
# 20250630     23  11260520  21684.5150   810.4878       403.4668
# 20250630     23  11260540  16575.0765   555.9794       281.4315
# 20250630     23  11650600  17385.1708   925.4452       388.0889
# 20250630     23  11680600  25429.5099  1267.1376      1763.1215
# 20250630     23  11260550  12535.5624   367.0228       204.1567
#
#           남자10세부터14세생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 20250601         342.0560         337.4781         339.0929         355.4220
# ...

# %%
df = pd.read_csv(
    "C:\Users\Admin\OneDrive\바탕 화면\새 폴더/자전거도로+현황(2002~2012)_20250711121250.csv",
    encoding="cp949")
# Out:
#   Cell In[8], line 2
#     "C:\Users\Admin\OneDrive\바탕 화면\새 폴더/자전거도로+현황(2002~2012)_20250711121250.csv",
#                                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df
# Out:
#                대여일자  대여소번호                      대여소 대여구분코드   성별   연령대   이용건수  \
# 0        2024-12-01    737                737. 장수공원    정기권  NaN  ~10대      1
# 1        2024-12-01   1153  1153. 발산역 1번, 9번 인근 대여소    정기권  NaN  ~10대      1
# 2        2024-12-01   1155            1155. 기쁜우리복지관    정기권  NaN  ~10대      1
# 3        2024-12-01   1442      1442. 중랑구청 중화동 별관 앞    정기권  NaN  ~10대      3
# 4        2024-12-01   1160        1160. 양천향교역 7번출구앞    정기권  NaN  ~10대      1
# ...             ...    ...                      ...    ...  ...   ...    ...
# 1410911  2024-12-31   3500            3500. 군자역2번출구    정기권    M    기타      1
# 1410912  2024-12-31   3504               3504. 원일교회    정기권    M    기타      1
# 1410913  2024-12-31    502  502. 자양(뚝섬한강공원)역 1번출구 앞    정기권    M    기타      1
# 1410914  2024-12-31    723              723. SBS방송국    정기권    M    기타      1
# 1410915  2024-12-31    726       726. 목동3단지 시내버스정류장    정기권    M    기타      1
#
#             운동량   탄소량  이동거리(M)  이용시간(분)
# ...

# %%
df = pd.read_csv("C:\Users\Admin\OneDrive\바탕 화면\새 폴더/유동인구.csv", encoding="cp949")
