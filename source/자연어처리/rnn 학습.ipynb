# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# <font size="5" color="red">RNN</font>
# # 1. 문맥을 이용하여 모델 만들기

# %%
text = """경마장에 있는 말이 뛰고 있다 
그의 말이 법이다
가는 말이 고아야 오는 말이 곱다"""
text1 = "장마철이 오고 있다"

# %%
from keras_preprocessing.text import Tokenizer

t = Tokenizer()

# Correct method to fit the tokenizer on the text
t.fit_on_texts([text, text1])

# Convert the texts to sequences
encoded = t.texts_to_sequences([text, text1])

# Print the encoded sequences
print(encoded)
print(t.word_index)
# Out:
# [[3, 4, 1, 5, 2, 6, 1, 7, 8, 1, 9, 10, 1, 11], [12, 13, 2]]
# {'말이': 1, '있다': 2, '경마장에': 3, '있는': 4, '뛰고': 5, '그의': 6, '법이다': 7, '가는': 8, '고아야': 9, '오는': 10, '곱다': 11, '장마철이': 12, '오고': 13}

# %%
from keras_preprocessing.text import Tokenizer

t = Tokenizer()

# Correct method to fit the tokenizer on the text
t.fit_on_texts([text])

# Convert the texts to sequences
encoded = t.texts_to_sequences([text])

# Print the encoded sequences
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고아야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5]]
# [8, 1, 11]

# %%
text = """경마장에 있는 말이 뛰고 있다 
그의 말이 법이다
가는 말이 고아야 오는말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고아야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는','경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i:시작index
        for j in range(i+2, len(encoded)+1): # j:끝나는 index바로 뒤
            sequences.append(encoded[i:j])
# print(sequences)
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고아야 오는말이 곱다
# encoded된 문장 : [8, 1, 9, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고아야
# 8:가는 1:말이 9:고아야 11:곱다
# 1:말이 9:고아야
# 1:말이 9:고아야 11:곱다
# 9:고아야 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 2, 3, 2]
# 5

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                padding='pre')
padded_sequences.shape, type(padded_sequences)
# Out:
# ((19, 5), numpy.ndarray)

# %%
# 독립변수(x)와 타겟변수(y)로 분리
x = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 11,  9,
#        11, 11])

# %%
# 컴퓨터가 엠베딩 작업할 때 필요한 입력 bit 수 (단어수+1)
input_dim = len(t.word_index) +1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, input_dim)
x.shape, y.shape
# Out:
# ((19, 4), (19, 12))

# %%
# 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding  # xi 의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim,      # 12개로 원핫 인코딩
                   output_dim=10,             # 임베딩 풀력의 갯수
                   input_length=x.shape[1]))  # 입력의 X 의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
# 모델 학습과정 설정
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# 모델학습 시키기
hist = model.fit(x, y, epochs=300, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 4, 10)             120
#
#  simple_rnn_1 (SimpleRNN)    (None, 32)                1376
#
#  dense_1 (Dense)             (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.4846 - accuracy: 0.1053 - 788ms/epoch - 788ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4735 - accuracy: 0.1053 - 5ms/epoch - 5ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4624 - accuracy: 0.1579 - 4ms/epoch - 4ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4512 - accuracy: 0.1579 - 4ms/epoch - 4ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4399 - accuracy: 0.2105 - 5ms/epoch - 5ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4283 - accuracy: 0.2105 - 5ms/epoch - 5ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4164 - accuracy: 0.2632 - 9ms/epoch - 9ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.4041 - accuracy: 0.2632 - 8ms/epoch - 8ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.3914 - accuracy: 0.2105 - 4ms/epoch - 4ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.3782 - accuracy: 0.2105 - 4ms/epoch - 4ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.
ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.5661 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.5542 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.5423 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.5303 - accuracy: 0.5789 - 6ms/epoch - 6ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.5183 - accuracy: 0.5789 - 6ms/epoch - 6ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.5061 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.4939 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.4816 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.4692 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.4568 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.4443 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.4318 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.4193 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.4067 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.3940 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.3814 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3687 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.3559 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.3432 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.3305 - accuracy: 0.5789 - 5ms/epoch - 5ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.3177 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.3050 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.2923 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2795 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2668 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.2542 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.2416 - accuracy: 0.5789 - 3ms/epoch - 3ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.2290 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.2164 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.2039 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.1915 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1791 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1668 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1545 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.1424 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.1303 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.1182 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.1063 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.0944 - accuracy: 0.5789 - 4ms/epoch - 4ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0827 - accuracy: 0.6316 - 4ms/epoch - 4ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0710 - accuracy: 0.6316 - 3ms/epoch - 3ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0594 - accuracy: 0.6316 - 4ms/epoch - 4ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0480 - accuracy: 0.6316 - 4ms/epoch - 4ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.0366 - accuracy: 0.6316 - 3ms/epoch - 3ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 1.0253 - accuracy: 0.6316 - 4ms/epoch - 4ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 1.0142 - accuracy: 0.6316 - 4ms/epoch - 4ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 1.0031 - accuracy: 0.6316 - 3ms/epoch - 3ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.9922 - accuracy: 0.6842 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9813 - accuracy: 0.7368 - 3ms/epoch - 3ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9706 - accuracy: 0.7368 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9600 - accuracy: 0.7368 - 4ms/epoch - 4ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.9495 - accuracy: 0.7368 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.9391 - accuracy: 0.7368 - 4ms/epoch - 4ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9289 - accuracy: 0.7368 - 4ms/epoch - 4ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9187 - accuracy: 0.7368 - 3ms/epoch - 3ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.9087 - accuracy: 0.7368 - 5ms/epoch - 5ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.8988 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.8890 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.8793 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.8697 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.8603 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.8509 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.8417 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8326 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8235 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8146 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8058 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.7972 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.7886 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.7801 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.7717 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.7634 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.7553 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.7472 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.7392 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7314 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7236 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7159 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7084 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7009 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.6935 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.6862 - accuracy: 0.7895 - 4ms/epoch - 4ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.6790 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.6719 - accuracy: 0.7895 - 5ms/epoch - 5ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.6649 - accuracy: 0.7895 - 3ms/epoch - 3ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.6580 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.6512 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.6444 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.6378 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6312 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6247 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6184 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6121 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6059 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.5997 - accuracy: 0.8421 - 5ms/epoch - 5ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.5937 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.5877 - accuracy: 0.8421 - 4ms/epoch - 4ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.5819 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.5761 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.5704 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.5647 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.5592 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.5537 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.5483 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.5430 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.5378 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5326 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5276 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5226 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5176 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5128 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5080 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5033 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.4987 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.4941 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.4896 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.4852 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.4808 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.4765 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.4723 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.4681 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.4640 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.4600 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.4560 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.4521 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.4482 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.4444 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.4407 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4370 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4334 - accuracy: 0.8947 - 6ms/epoch - 6ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4298 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4263 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4228 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4194 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4161 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4128 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4095 - accuracy: 0.8947 - 6ms/epoch - 6ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4064 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4032 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4001 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.3971 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.3941 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.3911 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.3882 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.3853 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.3825 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.3797 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.3770 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.3743 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.3717 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.3691 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.3665 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.3640 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.3615 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.3590 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.3566 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.3543 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.3519 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3496 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3474 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3451 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3429 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3408 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3387 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3366 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3345 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3325 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3305 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3285 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3266 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3247 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3228 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3209 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3173 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3155 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3138 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3121 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3104 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3087 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3071 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3055 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3039 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3023 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3008 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.2993 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.2978 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.2963 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.2948 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.2934 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.2920 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.2906 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.2892 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.2879 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.2865 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.2852 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.2839 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.2827 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.2814 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.2802 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.2790 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.2778 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.2766 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.2754 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.2743 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.2731 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.2720 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.2709 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.2698 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.2688 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.2677 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.2667 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.2657 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.2646 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.2636 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.2627 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.2617 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2607 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2598 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2589 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2580 - accuracy: 0.8947 - 6ms/epoch - 6ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2571 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2562 - accuracy: 0.8947 - 3ms/epoch - 3ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2553 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2544 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2536 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2527 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2519 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2511 - accuracy: 0.8947 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2503 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2495 - accuracy: 0.8947 - 17ms/epoch - 17ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2487 - accuracy: 0.8947 - 6ms/epoch - 6ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2479 - accuracy: 0.8947 - 5ms/epoch - 5ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2472 - accuracy: 0.8947 - 4ms/epoch - 4ms/step

# %%
import matplotlib.pyplot as plt

# 하나의 Figure + 2개의 y축 (왼쪽: 손실, 오른쪽: 정확도)
fig, loss_ax = plt.subplots(figsize=(12, 6))

# 왼쪽 y축: Loss
loss_ax.plot(hist.history['loss'], 'y', label='Train Loss')

loss_ax.set_xlabel('Epoch')
loss_ax.set_ylabel('Loss')


# 오른쪽 y축: Accuracy
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='Train Acc')

acc_ax.set_ylabel('Accuracy')


plt.show()

# %%
input_word = input('입력단어:')
# 입력 텍스트를 시퀀스로 변환
encoded = t.texts_to_sequences([input_word])[0]

# 시퀀스를 모델에 맞게 패딩 처리
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')

# 예측 결과 (argmax()를 사용하여 가장 높은 확률의 인덱스를 반환)
result = model.predict(input_data).argmax()

# 결과 인덱스를 단어로 변환
word = t.index_word[result]

# 예측된 단어 출력

print(word)
# Out:
# 입력단어:가는 말이
# 1/1 [==============================] - 0s 20ms/step
# 고아야

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %%
# "경마장에" 이후에 올 단어 3개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    # print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print("{}번째 생성 문맥 {} ({}{})".format(i,
#                                            current_word,
#                                            encoded,
#                                            result) )
    return current_word
sentence_generation('경마장에', 3)
# Out:
# '경마장에 있는 말이 뛰고'

# %%
sentence_generate('가는', 5)
# Out:
# 입력된 단어: 가는
# '가는말이말이말이말이말이'
