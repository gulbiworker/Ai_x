# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %% [markdown]
# <font size="5" color="red">ch04 제어문</font>
# # 1절. BeautifulSoup 과 parse
# - 공식사이트:

# %%
import requests
from requests_file import FileAdapter

# %%
s = requests.Session() # HTTP 요청관리를 위한 세션 객체
s.mount('file://',FileAdapter())
response = s.get('file:///Ai_x/source/01_python/data/ch14_sample.html')
response
# Out:
# <Response [200]>

# %%
response.status_code 
# 200 : 정상상태
# 404 : 없는페이지
# 406 : get, post 오류
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n  <meta charset="UTF-8">\r\n</head>\r\n<body>\r\n  <h1 class="greeting css" id="text">Hello, CSS</h1>\r\n  <h1 class="css">Hi, CSS</h1>\r\n  <div id="subject">subject \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90 \xec\x95\x88\xec\x9d\x98 \xeb\x82\xb4\xec\x9a\xa9</div>\r\n  <p>CSS \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb3\xb3\xec\x97\x90\xec\x84\x9c \xed\x99\x9c\xec\x9a\xa9\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4</p>\r\n  <div class="contents">\r\n    \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\xa5\xbc \xec\x96\xb4\xeb\x96\xbb\xea\xb2\x8c \xec\x9e\x91\xec\x84\xb1\xed\x95\x98\xeb\x8a\x90\xeb\x83\x90\xec\x97\x90 \xeb\x94\xb0\xeb\x9d\xbc\r\n    <span>\xeb\x8b\xa4\xeb\xa5\xb8<b>\xec\x9a\x94\xec\x86\x8c\xea\xb0\x80 \xeb\xb0\x98\xed\x99\x98</b></span>\xeb\x90\xa9\xeb\x8b\x88\xeb\x8b\xa4\r\n  </div>\r\n  <div>CSS \xec\x84\xa0\xed\x83\x9d\xec\x9e\x90\xeb\x8a\x94 \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xea\xb
# ...

# %%
response.content.decode('utf-8')
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n  <meta charset="UTF-8">\r\n</head>\r\n<body>\r\n  <h1 class="greeting css" id="text">Hello, CSS</h1>\r\n  <h1 class="css">Hi, CSS</h1>\r\n  <div id="subject">subject 선택자 안의 내용</div>\r\n  <p>CSS 선택자는 다양한 곳에서 활용됩니다</p>\r\n  <div class="contents">\r\n    선택자를 어떻게 작성하느냐에 따라\r\n    <span>다른<b>요소가 반환</b></span>됩니다\r\n  </div>\r\n  <div>CSS 선택자는 다양한 곳에 <b>활용</b>됩니다</div>\r\n</body>\r\n</html>'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, #response.text
                    "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# </head>
# <body>
# <h1 class="greeting css" id="text">Hello, CSS</h1>
# <h1 class="css">Hi, CSS</h1>
# <div id="subject">subject 선택자 안의 내용</div>
# <p>CSS 선택자는 다양한 곳에서 활용됩니다</p>
# <div class="contents">
#     선택자를 어떻게 작성하느냐에 따라
#     <span>다른<b>요소가 반환</b></span>됩니다
#   </div>
# <div>CSS 선택자는 다양한 곳에 <b>활용</b>됩니다</div>
# </body>
# </html>

# %%
el = soup.select_one('h1') #처음 나오는 h1태그 하나만
print('el:' ,el)
print('el.text:',el.text)
print('el.string:',el.string)
print('el 속성들:', el.attrs)
print('el의 title속성', el.attrs.get('title'))
print('el의 이름:',el.name)
# Out:
# el: <h1 class="greeting css" id="text">Hello, CSS</h1>
# el.text: Hello, CSS
# el.string: Hello, CSS
# el 속성들: {'class': ['greeting', 'css'], 'id': 'text'}
# el의 title속성 None
# el의 이름: h1

# %%
el = soup.select('h1')
print('리스트 el:',el)
print('el의 text들:',[e.text for e in el])
print('el의 속성들:',[e.attrs for e in el])
print('el의 class속성들:',[e.attrs.get('class') for e in el])
# Out:
# 리스트 el: [<h1 class="greeting css" id="text">Hello, CSS</h1>, <h1 class="css">Hi, CSS</h1>]
# el의 text들: ['Hello, CSS', 'Hi, CSS']
# el의 속성들: [{'class': ['greeting', 'css'], 'id': 'text'}, {'class': ['css']}]
# el의 class속성들: [['greeting', 'css'], ['css']]

# %%
# select
print('select_one:',soup.select_one('h1.css'))
print('find :',soup.find('h1',{'class':'css'}))
print('find :',soup.find('h1',class_='css'))
print()
print('select_one', soup.select_one('h1#text'))
print('find:', soup.find('h1',{'id':'text'}));
print('select')
# Out:
# select_one: <h1 class="greeting css" id="text">Hello, CSS</h1>
# find : <h1 class="greeting css" id="text">Hello, CSS</h1>
# find : <h1 class="greeting css" id="text">Hello, CSS</h1>
#
# select_one <h1 class="greeting css" id="text">Hello, CSS</h1>
# find: <h1 class="greeting css" id="text">Hello, CSS</h1>
# select

# %%
# select 와 find_all
print('보든 h1.css, span태그(select):'.
     soup.select('h1.css,span'))
print('모든h1.css, span태그(find_all):',
     soup.find_all(['h1','span'], class_='css'))

# %%
# 없는 엘리먼트 찾기
print('find_all:', soup.find_all('a', class_='css') )
print('find(NOne):', soup.find('a',class_='css'))
print('select:',soup.select('a.css'))
print('select_one(None):', soup.select_one('a.css'))
# Out:
# find_all: []
# find(NOne): None
# select: []
# select_one(None): None

# %% [markdown]
# # 2. 정적웹데이터 수집
# ## 2.1 json파일

# %%
# 방법1
import requests
response = requests.get('https://api.github.com')
response, response.status_code
# Out:
# (<Response [403]>, 403)

# %%
# 방법2
from urllib.request import urlopen
response =request.get('https://api.github.com')
response, response.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 # 방법2
#       2 from urllib.request import urlopen
# ----> 3 response =request.get('https://api.github.com')
#       4 response, response.status_code
#
# NameError: name 'request' is not defined

# %%
text = "{'속성1':'값1','속성2':'값2'}"
print(type(text))  # <class 'str'>
# Out:
# <class 'str'>

# %% [markdown]
# ## 2.2 html 파일

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://finance.naver.com/marketindex'
response = requests.get(url)
soup = BeautifulSoup(response.text,
                    'html.parser')

# %%
from urllib.request import urlopen
response = urlopen(url)
soup = BeautifulSoup(response, 'html.parser')

# %%
title = soup.select('h3.h_lst > span.blind')
for t in title:
    print(t.text, end='\t')
# Out:
# 미국 USD	일본 JPY(100엔)	유럽연합 EUR	중국 CNY	달러/일본 엔	유로/달러	영국 파운드/달러	달러인덱스	WTI	휘발유	국제 금	국내 금

# %%
price = soup.select('div.head_info.point_dn > span.value')
[p.text for p in price]
# Out:
# ['1,375.20',
#  '953.05',
#  '1,556.38',
#  '191.04',
#  '1.1342',
#  '1.3520',
#  '60.89',
#  '1633.17',
#  '3300.4']

# %%
out = '1,374.70'
float(''.join(out.split(',')))
# Out:
# 1374.7

# %%
out.replace(',','')
# Out:
# '1374.70'

# %%
price = soup.select('div.head_info > span.value')
[p.text for p in price]
[round(float(p.text.replace(',','')))for p in price]
[round(float(''.join()))for p in price]

# %%
unit = soup.select('div.head_info > span > span.blind')
unit = [u.text for u in unit]
unit.insert(7,'')
unit
# Out:
# ['원', '원', '원', '원', '엔', '달러', '달러', '', '달러', '원', '달러', '원']

# %%
status = soup.select('div.head_info > span.blind')
[t.text for t in title]
[p.text for p in price]
unit
[s.string for s in status]
# Out:
# ['하락', '하락', '하락', '하락', '상승', '하락', '하락', '상승', '하락', '하락', '하락', '상승']

# %%
for idx in range(len(title)):
    print('{} : {}{} - {}'.format(title[idx].text,
                                 price[idx].text,
                                 unit[idx],
                                 status[idx].text))
# Out:
# 미국 USD : 1,375.20원 - 하락
# 일본 JPY(100엔) : 953.05원 - 하락
# 유럽연합 EUR : 1,556.38원 - 하락
# 중국 CNY : 191.04원 - 하락
# 달러/일본 엔 : 1.1342엔 - 상승
# 유로/달러 : 1.3520달러 - 하락
# 영국 파운드/달러 : 60.89달러 - 하락
# 달러인덱스 : 1633.17 - 상승
# WTI : 3300.4달러 - 하락
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 3
#       1 for idx in range(len(title)):
#       2     print('{} : {}{} - {}'.format(title[idx].text,
# ----> 3                                  price[idx].text,
#       4                                  unit[idx],
#       5                                  status[idx].text))
#
# IndexError: list index out of range

# %%
for t, p, u, s in zip(title, price, unit, status):
    print('{} : {}{} - {}'.format(t.text,
                                 p.text,
                                 u,
                                 s.text))
# Out:
# 미국 USD : 1,375.20원 - 하락
# 일본 JPY(100엔) : 953.05원 - 하락
# 유럽연합 EUR : 1,556.38원 - 하락
# 중국 CNY : 191.04원 - 하락
# 달러/일본 엔 : 1.1342엔 - 상승
# 유로/달러 : 1.3520달러 - 하락
# 영국 파운드/달러 : 60.89달러 - 하락
# 달러인덱스 : 1633.17 - 상승
# WTI : 3300.4달러 - 하락

# %% [markdown]
# ## 로또

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://dhlottery.co.kr/gameResult.do?method=byWin&wiselog=C_A_1_1'
response = requests.get(url)
soup = BeautifulSoup(response.text,
                    'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="동행복권" id="utitle" name="title"/>
# <meta content="동행복권 1173회 당첨번호 1,5,18,20,30,35+3. 1등 총 24명, 1인당 당첨금액 1,179,946,063원." id="desc" name="description"/>
# <title>로또6/45 - 회차별 당첨번호</title>
# <title>동행복권</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/images/common/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/images/common/favicon.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.js" type="text/javascript"></script>
# <script charset="utf-8" src="/js/common.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# fn_g_init_message("");
#
# var gameUserId = "";
#
# function goGame(){
# 	var userId = "";
#
# 	if(userId == '' || userId == null){
# 		alert("로그인 후 사용 해주시기 바랍니다.");
# 		location.href = "/user.do?method=login";
# 		return;
# 	}
# ...

# %%
title = soup.select('utitle')
for t in title:
    print(t.text, end='\t')

# %%
times = soup.select_one('div.win_result>h4>strong').text
date = soup.select_one('div.win_result>p.desc').text
print(times, date)
# Out:
# 1173회 (2025년 05월 24일 추첨)

# %%
times = soup.select_one('div.win_result > h4 > strong').text # 1173회
date = soup.select_one('div.win_result >p.desc').text  #(2025년 05월 24일 추첨)
print(times, date)
title1 = soup.select_one('div.num.win > strong').text
lotto_number = soup.select('div.nums>div.num.win > p > span')
print(title1, [int(lotto.text) for lotto in lotto_number])
title2 = soup.select_one('div.num.bonus > strong').string
bonus_number = soup.select_one('div.num.bonus > p > span').text
print(title2, bonus_number)
# Out:
# 1173회 (2025년 05월 24일 추첨)
# 당첨번호 [1, 5, 18, 20, 30, 35]
# 보너스 3

# %%
# 위의 select 함수를 find함수로
#times = soup.select_one('div.win_result > h4 > strong').text # 1173회
win_result = soup.find('div', class_="win_result")
# date = soup.select_one('div.win_result >p.desc').text  #(2025년 05월 24일 추첨)
# print(times, date)
# title1 = soup.select_one('div.num.win > strong').text
# lotto_number = soup.select('div.num.win > p > span')
# print(title1, [int(lotto.text) for lotto in lotto_number])
# title2 = soup.select_one('div.num.bonus > strong').string
# bonus_number = soup.select_one('div.num.bonus > p > span').text
# print(title2, bonus_number)

# %% [markdown]
# # 3 다음검색

# %%
keyword = '비트코인'
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8'+ keyword
response = requests.get(url)
soup = BeautifulSoup(response.text,"html.parser")
items_find_list = []
items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
for idx,item in enumerate(items_el):
    items_find_list.append({'no' : idx,
                           'title': item.text,
                           'link':item.attrs['href']})
import pandas as pd
pd.DataFrame(items_find_list)
# Out:
#    no                                              title  \
# 0   0   [비트코인 2025] 백악관 크립토 차르 “美 정부 비트코인 추가 매입 검토…부채...
# 1   1   EU관세 발언 후 10만8000달러선 회복 비트코인…파키스탄 ‘비트코인 채굴’ 전...
# 2   2                       숨 고르는 비트코인, 10만8000달러선 '주춤'
# 3   3            [비즈 나우] 비트코인 2025 컨퍼런스 개막…'전략자산' 선언 코앞
# 4   4             "비트코인 산다"…트럼프家, 25억달러 자금 조달 추진[코인브리핑]
# 5   5                비트코인, 트럼프 미디어 비축 소식에도 주춤…1억5100만원대
# 6   6                 '비트코인 빚투' 스트레티지, 또 샀다…보유량 58만개 돌파
# 7   7              10만 달러, 11만 달러… 트럼프 관세 변덕에 비트코인 '출렁'
# 8   8             '해킹 산업화'의 원흉 '비트코인'…위치추적 안 되자 활개[은폐⑥]
# 9   9                        美 상원의원 "트럼프 대통령, 비트코인법 지지"
#
#                                     link
# 0  http://v.daum.net/v/20250528103907230
# 1  http://v.daum.net/v/20250526080440640
# 2  http://v.daum.net/v/20250528095921258
# 3  http://v.daum.net/v/20250528075215864
# 4  http://v.daum.net/v/20250528111837527
# 5  http://v.daum.net/v/20250528095112897
# 6  http://v.daum.net/v/20250528042404292
# ...

# %%
import requests
from bs4 import BeautifulSoup
word = '비트코인'
word = urllib.parse.quote(word)
print(word)
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q='+word
response = urlopen(url)
soup = BeautifulSoup(response.text,"html.parser")
items_find_list = []
tems_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
for idx,item in enumerate(items_el):
    items_find_list.append([idx, item.text, item.attrs.get('href')])
import pandas as pd
pd.DataFrame(items_find_list, columns=['no','title','link'])
# Out:
# Empty DataFrame
# Columns: [no, title, link]
# Index: []

# %%
# 다음 뉴스 검색(키워드, 원하는 페이지 수)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
keyword = '비트코인'
page = 2
url = f'https://m.search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&q=&p='
params = {'q':keyword, 'p':page}
response = requests.get(url, params=params)
soup = BeautifulSoup(response.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="application/xhtml+xml; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="always" name="referrer"/>
# <meta content="no-cache" http-equiv="Cache-Control">
# <meta content=" - Daum 검색" property="og:title"/>
# <meta content="https://m.search.daum.net/search?w=news&amp;nil_search=btn&amp;DA=PGD&amp;enc=utf8&amp;cluster=y&amp;q=&amp;p=&amp;q=%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8&amp;p=2" property="og:url"/>
# <meta content="Daum 검색" property="og:site_name">
# <meta content="https://search1.daumcdn.net/search/statics/common/img/20250107/daum_og.png" property="og:image"/>
# <meta content="Daum 검색에서 에 대한 최신정보를 찾아보세요." property="og:description"/>
# ...

# %%
# 다음 뉴스 검색(키워드, 원하는 페이지수)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
keyword = '비트코인'
page = 2
# url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y&q={keyword}&p={page}'
# response = requests.get(url)
url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y'
params = {'q':keyword, 'p':page}
response = requests.get(url, params=params)
soup = BeautifulSoup(response.text,  # response.content
                    'html.parser')
items_find_list = [] # 검색한 결과를 담을 dict list
items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
# len(items_el)
for idx, item in enumerate(items_el):
    items_find_list.append({'no': (page-1)*10 + idx,
                           'title': item.text,
                           'link': item.attrs['href']})
    print({'no': (page-1)*10 + idx,
           'title': item.text,
           'link': item.attrs['href']})
# Out:
# {'no': 10, 'title': ' [비트코인 2025] 로빈후드 창업자 “토큰화 증권은 美 ‘자본 패권’ 키우는 수단” ', 'link': 'http://v.daum.net/v/20250528110600761'}
# {'no': 11, 'title': ' 트럼프미디어그룹, 25억 달러 규모 자금 조달 통해 비트코인 매입 예고 ', 'link': 'http://v.daum.net/v/20250528084245020'}
# {'no': 12, 'title': ' 연일 최고가 경신하는 비트코인…투자자들 강 건너 불구경하는 이유는 ', 'link': 'http://v.daum.net/v/20250526212400275'}
# {'no': 13, 'title': ' "비트코인 산다"…트럼프家, 25억달러 자금 조달 추진[코인브리핑] ', 'link': 'http://v.daum.net/v/20250528111837527'}
# {'no': 14, 'title': ' [김대호 박사의 오늘의 키워드] 소비자신뢰지수·비트코인 2025·머스크 한마디·애플 괘씸죄 ', 'link': 'http://v.daum.net/v/20250528071325361'}
# {'no': 15, 'title': ' 잘 나가는 비트코인 산다는데 왜?…트럼프 미디어 주가 10% 급락 [투자360] ', 'link': 'http://v.daum.net/v/20250528074002668'}
# {'no': 16, 'title': ' "테슬라 팔고 갈아탔어요"…자녀계좌 보던 엄마들 \'돌변\' [마켓PRO] ', 'link': 'http://v.daum.net/v/20250528094602647'}
# {'no': 17, 'title': ' 스트래티지, 비트코인 4020개 추가 매입...보유량 58만개 돌파 ', 'link': 'http://v.daum.net/v/20250527081116129'}
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
def collect_list(keyword, page=1):
    'keyword로 다음 검색한 결과(해당 page)를 return'
    url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y'
    params = {'q':keyword, 'p':page}
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.text,  # response.content
                    'html.parser')
    items_find_list = [] # 검색한 결과를 담을 dict list
    items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
    for idx, item in enumerate(items_el):
        items_find_list.append({'no': (page-1)*10 + idx,
                           'title': item.text,
                           'link': item.attrs['href']})
    return items_find_list

# %%
collect_list('대선투표',2)
# Out:
# [{'no': 10,
#   'title': " 공약집 없이 대선 투표 시작… 가열되는 '비방전' 투표율 낮출라 ",
#   'link': 'http://v.daum.net/v/20250524123705877'},
#  {'no': 11,
#   'title': " '시장 스타일 구기는 것 쯤이야'…광명시, 대선투표 독려 영상 화제 ",
#   'link': 'http://v.daum.net/v/20250528100556682'},
#  {'no': 12,
#   'title': " 국민의힘 방세환 광주시장, 대선 투표참여 독려 '눈길' ",
#   'link': 'http://v.daum.net/v/20250527155213156'},
#  {'no': 13,
#   'title': ' 전남도, 대선 투표 참여 캠페인 ',
#   'link': 'http://v.daum.net/v/20250528112007618'},
#  {'no': 14,
#   'title': ' 대선 투표참여 홍보에 발벗고 나선 김영록 지사 ',
#   'link': 'http://v.daum.net/v/20250527144205460'},
#  {'no': 15,
#   'title': ' <호텔소식> 센텀비즈니스호텔 "대선 투표 인증샷, 당일 선착순 1박 무료" ',
#   'link': 'http://v.daum.net/v/20250527112515888'},
#  {'no': 16,
#   'title': ' ‘대선’ 투표 참여 독려하는 강북구…홍보 현수막·배너 설치 ',
#   'link': 'http://v.daum.net/v/20250527141101069'},
#  {'no': 17,
#   'title': ' [동정] 권익현 부안군수, 대선 투표 독려 캠페인 동참 ',
#   'link': 'http://v.daum.net/v/20250528135202999'},
#  {'no': 18,
# ...

# %%
# 원하는 keyword로 다음 검색
result = []
keyword = '청바지'
pages = 4
for page in range(1, pages+1):
    print(page)
    result.extend(collect_list(keyword, page))
    time.sleep(3)
pd.DataFrame(result)
# Out:
# 1
# 2
# 3
# 4
#     no                                              title  \
# 0    0                      '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑
# 1    1            “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’
# 2    2                              흰 티셔츠에 청바지 정석대로 입는 법
# 3    3          이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ)
# 4    4   ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나...
# 5    5                이시영처럼 다리 길어보이고 싶어서 청바지 분석함 [입스타그램]
# 6    6           '의사 그만둔' 고윤정, 흰 티+청바지..."정석 미녀" [★해시태그]
# 7    7           "청렴이 최고" … 창원특례시 성산구 문화위생과, '청바지 데이' 추진
# 8    8                  패셔니스타 김지원, 청바지가 어울리는 여자랍니다! [포토]
# 9    9                    박병은 "류준하로 3개월 활동"…청바지 모델 시절 언급
# 10  10                             60대인데요, 청바지를 다시 입었습니다
# 11  11           '45kg' 윤은혜, 청바지가 헐렁…'40세' 비현실적 자기관리 끝판왕
# 12  12            173㎝ 장원영 맵시 美쳤네, 청바지 하나 입었을 뿐인데 [스타화보]
# 13  13                손담비, 출산 한 달도 안 됐는데 외출…청바지 폼 애엄마 맞나
# 14  14              48세 김희선, 흰 셔츠+청바지 기본템 입었을 뿐인데‥미모 레전드
# ...

# %%
keywords = ['청바지','면바지']
pages = 5
result0 = [] # 청바지 검색결과 50
result1 = [] # 면바지 검색결과 50
for i, keyword in enumerate(keywords):
    for page in range(1, pages+1):
        print(f'{i}번쨰{keyword} {page} 검색중')
        if i==0:
            result0.extend(collect_list(keyword, page))
        else:
            result1.extend(collect_list(keyword, page))
            time.sleep(3)
# Out:
# 0번쨰청바지 1 검색중
# 0번쨰청바지 2 검색중
# 0번쨰청바지 3 검색중
# 0번쨰청바지 4 검색중
# 0번쨰청바지 5 검색중
# 1번쨰면바지 1 검색중
# 1번쨰면바지 2 검색중
# 1번쨰면바지 3 검색중
# 1번쨰면바지 4 검색중
# 1번쨰면바지 5 검색중

# %%
result0_df = pd.DataFrame(result0)
result0_df.head()
# Out:
#    no                                              title  \
# 0   0                      '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑
# 1   1            “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’
# 2   2                              흰 티셔츠에 청바지 정석대로 입는 법
# 3   3          이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ)
# 4   4   ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나...
#
#                                     link
# 0  http://v.daum.net/v/20250528050507783
# 1  http://v.daum.net/v/20250526182411395
# 2  http://v.daum.net/v/20250527185425864
# 3  http://v.daum.net/v/20250527191015309
# 4  http://v.daum.net/v/20250527192310643

# %%
result1_df = pd.DataFrame(result1)
result1_df.head()
# Out:
#    no                                              title  \
# 0   0                     사천에서 쾌청한 날씨 속 탁 트인 남해 풍경 즐겨요!
# 1   1            윤승아, ♥김무열 쏙 빼닮은 깜찍 子 하객룩 공개‥벌써 우월한 유전자
# 2   2                           이번 주 포천 여행,반팔 하나로 충분할까?
# 3   3                              이재명, 첫 대학 방문…이준석 겨냥?
# 4   4   "나는 젊어" 팔소매 접은 이준석의 '흰셔츠' 속에도 뼈가 담겼다[21대 대선 리...
#
#                                     link
# 0  http://v.daum.net/v/20250528104429529
# 1  http://v.daum.net/v/20250526145941690
# 2  http://v.daum.net/v/20250527171732518
# 3  http://v.daum.net/v/20250526191942751
# 4  http://v.daum.net/v/20250525070013619

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
def collect_list(keyword, page=1):
    'keyword로 다음 검색한 결과(해당 page)를 return'
    url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y'
    params = {'q':keyword, 'p':page}
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.text,  # response.content
                    'html.parser')
    items_find_list = [] # 검색한 결과를 담을 dict list
    items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
    for idx, item in enumerate(items_el):
        items_find_list.append({'no': (page-1)*10 + idx,
                           'title': item.text,
                           'link': item.attrs['href']})
    return items_find_list
collect_list("청바지", 1)
# Out:
# [{'no': 0,
#   'title': " '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑 ",
#   'link': 'http://v.daum.net/v/20250528050507783'},
#  {'no': 1,
#   'title': ' “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’ ',
#   'link': 'http://v.daum.net/v/20250526182411395'},
#  {'no': 2,
#   'title': ' 흰 티셔츠에 청바지 정석대로 입는 법 ',
#   'link': 'http://v.daum.net/v/20250527185425864'},
#  {'no': 3,
#   'title': ' 이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ) ',
#   'link': 'http://v.daum.net/v/20250527191015309'},
#  {'no': 4,
#   'title': ' ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나는 즉흥적”(이민정 MJ) ',
#   'link': 'http://v.daum.net/v/20250527192310643'},
#  {'no': 5,
#   'title': ' 이시영처럼 다리 길어보이고 싶어서 청바지 분석함 [입스타그램] ',
#   'link': 'http://v.daum.net/v/20250519172231644'},
#  {'no': 6,
#   'title': ' \'의사 그만둔\' 고윤정, 흰 티+청바지..."정석 미녀" [★해시태그] ',
#   'link': 'http://v.daum.net/v/20250522182007490'},
#  {'no': 7,
#   'title': ' "청렴이 최고" … 창원특례시 성산구 문화위생과, \'청바지 데이\' 추진 ',
#   'link': 'http://v.daum.net/v/20250511091428626'},
# ...

# %%
result0_df.to_csv('data/ch14_'+keywords[0]+'.csv',index=False, encoding='cp949')
result1_df.to_csv('data/ch14_'+keywords[1]+'.csv',index=False)

# %% [markdown]
# ### 4) user-agent를 추가하여 크롤링
# -urlopen()함수를 사용하면 롤링이 안되는 사이트
# -user-agent를 추가하여 크롤링

# %%
# 방법2
from urllib.request import urlopen, Request
import urllib.parse
word = '비트코인'
word = urllib.parse.quote(word)
# print(word)
url = 'https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q='+word
# User-Agent를 추가하여 브라우저처럼 보이게 포장
headers = {'user-agent':
         'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'}
request = Request(url, headers=headers)
response = urlopen(request)
soup = BeautifulSoup(response, # response.content
                    "html.parser")
def collect_list(keyword, page=1):
    'keyword로 다음 검색한 결과(해당 page)를 return'
    url = f'https://search.daum.net/search?w=news&nil_search=btn&DA=PGD&enc=utf8&cluster=y'
    params = {'q':keyword, 'p':page}
    response = requests.get(url, params=params)
    soup = BeautifulSoup(response.text,  # response.content
                    'html.parser')
    items_find_list = [] # 검색한 결과를 담을 dict list
    items_el = soup.select('div.item-title > strong.tit-g.clamp-g > a')
    for idx, item in enumerate(items_el):
        items_find_list.append({'no': (page-1)*10 + idx,
                           'title': item.text,
                           'link': item.attrs['href']})
    return items_find_list
collect_list("청바지", 1)
# Out:
# [{'no': 0,
#   'title': " '이병헌♥' 이민정, 매장 통째로 빌려 청바지 쇼핑 ",
#   'link': 'http://v.daum.net/v/20250528050507783'},
#  {'no': 1,
#   'title': ' “추앙받을 만 하네”… 김지원, 셔츠에 청바지만 입어도 공항 ‘정지’ ',
#   'link': 'http://v.daum.net/v/20250526182411395'},
#  {'no': 2,
#   'title': ' 흰 티셔츠에 청바지 정석대로 입는 법 ',
#   'link': 'http://v.daum.net/v/20250527185425864'},
#  {'no': 3,
#   'title': ' 이민정, 매장 빌려 폭풍 쇼핑 "10년 전 샀던 청바지는 응급실"(MJ) ',
#   'link': 'http://v.daum.net/v/20250527191015309'},
#  {'no': 4,
#   'title': ' ‘이병헌♥’ 이민정, 청바지 사는데 매장 통째로 빌렸다..남다른 쇼핑 클래스 “나는 즉흥적”(이민정 MJ) ',
#   'link': 'http://v.daum.net/v/20250527192310643'},
#  {'no': 5,
#   'title': ' 이시영처럼 다리 길어보이고 싶어서 청바지 분석함 [입스타그램] ',
#   'link': 'http://v.daum.net/v/20250519172231644'},
#  {'no': 6,
#   'title': ' \'의사 그만둔\' 고윤정, 흰 티+청바지..."정석 미녀" [★해시태그] ',
#   'link': 'http://v.daum.net/v/20250522182007490'},
#  {'no': 7,
#   'title': ' "청렴이 최고" … 창원특례시 성산구 문화위생과, \'청바지 데이\' 추진 ',
#   'link': 'http://v.daum.net/v/20250511091428626'},
# ...

# %% [markdown]
# # 유저 에이전트만 가능한 사이트

# %%
# 방법1 불가능
import requests
from bs4 import BeautifulSoup
url = 'https://www.melon.com/chart/'
melonpage = requests.get(url)
melonpage
# Out:
# <Response [406]>

# %%
# 방법2 에러남
from urllib.request import urlopen, Request
# melonpage = urlopen(url)

# %%
# 유저에이전트 추가
heaers = headers = {'user-agent':
         'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36'
         }
# 방법2
request = Request(url, headers=headers)
melonpage = urlopen(request)
# 방법1
melonpage = requests.get(url, headers=headers)
soup = BeautifulSoup(melonpage.text, # melonpage.content
                    'html.parser')
#soup

# %%
# 멜론순위, 노래제목, 가수, 좋아요갯수

# %%
melonpage = requests.get(url, headers=headers)
soup = BeautifulSoup(melonpage.text, # melonpage.content
                    'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="4022717807957185" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/" property="og:url"/>
# <meta content="website" property="og:type"/>
# ...

# %%
chart = soup.select_one('td>div.wrap.t_center>span.rank').text
title = soup.select_one('div.wrap_song_info>div.ellipsis.rank01>span>a').text
singer= soup.select_one('div.ellipsis.rank02>span.checkEllipsis').text
print(chart, title,singer)
# Out:
# 1 너에게 닿기를 10CM

# %%
title_els = soup.select('div.wrap_song_info>div.ellipsis.rank01>span>a')
singer_els = soup.select('div.ellipsis.rank02>span.checkEllipsis')
for idx, (title, singer) in enumerate(zip(title_els, singer_els)):
    print(f'{idx+1}위,제목:{title.text.strip()}, 가수{singer.text}')
# Out:
# 1위,제목:너에게 닿기를, 가수10CM
# 2위,제목:Never Ending Story, 가수아이유
# 3위,제목:Drowning, 가수WOODZ
# 4위,제목:like JENNIE, 가수제니 (JENNIE)
# 5위,제목:모르시나요(PROD.로코베리), 가수조째즈
# 6위,제목:THUNDER, 가수세븐틴 (SEVENTEEN)
# 7위,제목:TOO BAD (feat. Anderson .Paak), 가수G-DRAGON
# 8위,제목:네모의 꿈, 가수아이유
# 9위,제목:Whiplash, 가수aespa
# 10위,제목:HOME SWEET HOME (feat. 태양, 대성), 가수G-DRAGON
# 11위,제목:나는 반딧불, 가수황가람
# 12위,제목:어제보다 슬픈 오늘, 가수우디 (Woody)
# 13위,제목:오늘만 I LOVE YOU, 가수BOYNEXTDOOR
# 14위,제목:REBEL HEART, 가수IVE (아이브)
# 15위,제목:HAPPY, 가수DAY6 (데이식스)
# 16위,제목:빨간 운동화, 가수아이유
# 17위,제목:Flower, 가수오반(OVAN)
# 18위,제목:APT., 가수로제 (ROSÉ), Bruno Mars
# 19위,제목:청춘만화, 가수이무진
# 20위,제목:HOT, 가수LE SSERAFIM (르세라핌)
# 21위,제목:10월 4일, 가수아이유
# 22위,제목:한 페이지가 될 수 있게, 가수DAY6 (데이식스)
# 23위,제목:Last Scene (Feat. 원슈타인), 가수아이유
# 24위,제목:HBD, 가수세븐틴 (SEVENTEEN)
# 25위,제목:MY LOVE(2025), 가수이예은, 아샤트리, 전건호
# 26위,제목:그날이 오면, 가수투모로우바이투게더
# 27위,제목:내게 사랑이 뭐냐고 물어본다면, 가수로이킴
# 28위,제목:Fly Up, 가수RIIZE
# 29위,제목:Welcome to the Show, 가수DAY6 (데이식스)
# 30위,제목:소나기, 가수이클립스 (ECLIPSE)
# 31위,제목:천상연, 가수이창섭
# ...

# %% [markdown]
# ## 5) 네이버 활용

# %%
# 방법1
from requests import get
keyword = '쳇지피티'
url='https://kin.naver.com/search/list.naver?query={}'.format(keyword)
response = get(url)
soup = BeautifulSoup(response.text,
                    'html.parser')

# %%
# 방법2
from urllib.request import urlopen
from urllib.parse import quote
keyword = quote(keyword)
url='https://kin.naver.com/search/list.naver?query={}'.format(keyword)
response = urlopen(url)

# %%
# 페이지 포함
import requests
from bs4 import BeautifulSoup
import pandas as pd
keyword = '쳇지피티'
pages = 3
items_list = []
for page in range(1, pages+1):
    url =f'https://kin.naver.com/search/list.naver?query={keyword}&page={page}'
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    dts = soup.find_all('dt')
    for dt in dts:
        item = dt.find('a')
        items_list.append([item.text, item.attrs.get('href')])
df = pd.DataFrame(items_list, columns=['title','link'])
df
# Out:
#                       title                                               link
# 0                쳇지피티 논문 출처  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 1                   쳇지피티 한도  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 2             쳇지피티 사용 확인 AI  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 3   쳇지피티 이거 뭐예요?해킹 뭐그런거...   https://kin.naver.com/qna/detail.naver?d1id=1&...
# 4           쳇지피티 ai 소라 질문이요  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 5                  쳇지피티 초기화  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 6               학교 생기부 쳇지피티  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 7          제가 직접 쓴 자소서 쳇지피티  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 8               쳇지피티 질문입니다.  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 9                쳇지피티 채팅 문제  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 10                  쳇지피티 뤼튼  https://kin.naver.com/qna/detail.naver?d1id=8&...
# ...

# %%
# 함수
def get_items_data(keyword, pages):
    import requests
    from bs4 import BeautifulSoup
    import pandas as pd
    keyword = '쳇지피티'
    pages = 3
    items_list = []
    for page in range(1, pages+1):
        url =f'https://kin.naver.com/search/list.naver?query={keyword}&page={page}'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        dts = soup.find_all('dt')
        for dt in dts:
            item = dt.find('a')
            items_list.append([item.text, item.attrs.get('href')])
    return pd.DataFrame(items_list, columns=['title','link'])

# %%
df = get_items

# %% [markdown]
# ## 지식인 검색
#  - .env에 발급받은 키 저장 -> load

# %%
# 환경변수가져오기
from dotenv import load_dotenv
import os
load_dotenv() #기본값이 .env 이다
#print(os.getenv('Client_ID'))
#print(os.getenv('Client_Secret'))
# Out:
# True

# %%
#네이버 활용 ()
import os
import sys
import urllib.request
client_id = os.getenv('Client_ID')
client_secret = os.getenv('Client_Secret')
encText = urllib.parse.quote("쳇지피티")
data = "source=ko&target=en&text=" + encText
url = "https://openapi.naver.com/v1/search/kin.json?query=" + encText

headers = {'X-Naver-Client-Id': client_id,
          'X-Naver-Client-Secret' : client_secret}
request = urllib.request.Request(url, headers=headers)
#request = urllib.request.Request(url)
#request.add_header("X-Naver-Client-Id",client_id)
#request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(type(response_body.decode('utf-8')))
    import json
    data = json.loads(response_body.decode('utf-8'))
    print(type(data))
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <class 'str'>
# <class 'dict'>
# {
# 	"lastBuildDate":"Thu, 29 May 2025 12:37:35 +0900",
# 	"total":1953,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>쳇지피티<\/b> 논문 출처",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=4&dirId=40608&docId=471249146&qb=7LOH7KeA7ZS87Yuw&enc=utf8",
# 			"description":"<b>쳇지피티<\/b>한테 어떤 내용에 관한 논문을 요구하고, 해당... 지피티가 스스로 여러 논문을 합쳐서 저에게 정보를 제공해준 건가요? 안녕하세요 <b>쳇지피티<\/b>가 작성한 글은 내용을... 그러니 전적으로 <b>쳇지피티<\/b>를 의지 하지 말라고 말씀드리고... "
# 		},
# 		{
# 			"title":"<b>쳇지피티<\/b> 한도",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=1&dirId=1060101&docId=484917198&qb=7LOH7KeA7ZS87Yuw&enc=utf8",
# 			"description":"<b>쳇지피티<\/b> 무료로 쓰고 있는데 <b>쳇지피티<\/b>로 소설 하나 쓰고 있거든요 근데 한도가 초과됐다고 5시간 뒤에 다시 사용하라는데.. 5시간 뒤에 다시 이어서 쓸 수 있나요? 아니면 이미 한도 초과되서 다시 이어서 쓰는게 아예 안 되나요 5시간... "
# 		},
# 		{
# 			"title":"<b>쳇지피티<\/b> 사용 확인 AI",
# ...

# %%
# keyword를 display수만큼 지식in검색 결과를 데이터프레임에(방법1 크롤링)
def get_naver_kin(keyword, cnt):
    import requests
    import pandas as pd
    import json
    from dotenv import load_dotenv
    import os
    load_dotenv()
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')

    url = f'https://openapi.naver.com/v1/search/kin.json?query={keyword}&display={cnt}'
    headers = {'X-Naver-Client-Id': client_id,
              'X-Naver-Client-Secret' : client_secret}
    response = requests.get(url, headers=headers)
    #response.status_code
    items = json.loads(response.text)['items']
    items_list = []
    for item in items:
        items_list.append([
            item.get('title').replace('<b>','').replace('</b>',''),
            item.get('link'),
            item.get('description')
        ])
    return pd.DataFrame(items_list, columns=['title','link','discription'])

# %%
get_naver_kin('청바지', 20)
# Out:
#                              title  \
# 0                 영어로 청바지를 뭐라고하나요?
# 1   전 남자인데, 누워서 청바지를 입으면 고환이 아플 수?
# 2                청바지 없는데 면접취소 할까요?
# 3                   고관절 지방이식 후 청바지
# 4                   임영웅 청바지 입은 사진?
# 5                           청바지 세탁
# 6   미국에서 청바지 가격이 306불입니다 관부가세 얼마나오
# 7             청바지? 면바지도 트레이닝바지인가요?
# 8                        핀턱 청바지 수선
# 9                           청바지 이염
# 10      골프 연습장 에서 부츠컷 청바지 입어도 되나요?
# 11                    강아지 청바지 뜯어먹음
# 12                          청바지 수선
# 13              청바지는 오랫동안 쓸 수 있나요?
# 14       여자들중에 원피스보다 청바지가 예쁜 이유는요?
# 15          체육대회때 흰티에 청바지 입어도 되나요?
# 16                   8월 초 이탈리아 청바지
# 17              청바지는 오랫동안 쓸 수 있나요?
# 18                      청바지에서 파란 물
# 19               40대 남자도 청바지를 입나요?
#
#                                                  link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=11...
# 1   https://kin.naver.com/qna/detail.naver?d1id=7&...
# ...

# %% [markdown]
# ### quiz 네이버 이용하여 청바지 이미지 100건 데이터를 csv로 저장할것

# %%
def get_naver_img(word, display=100):
    import requests
    from dotenv import load_dotenv
    import os
    load_dotenv()
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')
    word='청바지'
    url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'    
    headers = {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret
    }
    response = requests.get(url, headers=headers)
    
    items = json.loads(response.text)['items']
    items_list = []
    for item in items:
        items_list.append({
            'title': item.get('title'),
            'link' : item.get('link'),
            'thumbnail' : item.get('thumbnail'),
            'sizeheight' : item.get('sizeheight'),
            'sizewidth' : item.get('sizewidth')})
    return pd.DataFrame(items_list, columns=['title', 'link', 'description'])

# %%
get_naver_img('청바지', 100)
df.to_csv('청마지_이미지검색결과.csv', index=False, encoding='utf-8-sig')

# %%
# CSV 불러오기 및 데이터 확인
import pandas as pd
from IPython.display import Image, display

# CSV 읽기
df = pd.read_csv('청마지_이미지검색결과.csv', encoding='utf-8-sig')

# 앞부분 미리보기
# Out:
#                                                title  \
# 0  청마지 마니아! 서지혜가 추천하는 가을 데님 룩! - kakaoTV 청마지 마니아!...
# 1              정석몰 여성 학생 카드 지갑 반지갑 선물용지갑 쌈지 청마지코디 민트
# 2  심플,이쁨,코디북,어디서나,앵클부츠,화이트,하얀,초록,그린,청마지... 심플,이쁨,...
# 3            셀프단추집게 청마지 치마 허리 줄이기 수선 허리줄임 단추 : 뽀록세일즈
# 4  클래식 BUT 촌스럽지 않게! 남자 직장인 출근룩 14일 돌려입기 : 더 케이커 클...
#
#                                                 link  description
# 0  http://t1.daumcdn.net/tvpot/thumb/s5546rrw8krr...          NaN
# 1  http://shopping.phinf.naver.net/main_5256457/5...          NaN
# 2  https://i3.codibook.net/files/1976062140624/36...          NaN
# 3  http://shop1.phinf.naver.net/20220822_218/1661...          NaN
# 4  https://i.pinimg.com/474x/a5/d9/36/a5d936d7f10...          NaN

# %%
    import requests
    from dotenv import load_dotenv
    import os
    load_dotenv()
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')
    word='청바지'
    url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'    
    headers = {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret
    }
    response = requests.get(url, headers=headers)
    
    items = json.loads(response.text)['items']
    items_list = []
    for item in items:
        items_list.append({
            'title': item.get('title'),
            'link' : item.get('link'),
            'thumbnail' : item.get('thumbnail'),
            'sizeheight' : item.get('sizeheight'),
            'sizewidth' : item.get('sizewidth')})
        df = pd.DataFrame(items_list)
        df.head(2)

# %%
df.head(2)
# Out:
#                                           title  \
# 0  BINIWU 심플 빈티지 워싱 청바지 남자 봄가을 루즈핏 통바지 28 빈티지블루
# 1               중년 청바지 아이스 팬츠 남성 얇은 슬랙스 바지남 긴바지
#
#                                                 link  \
# 0  http://shopping.phinf.naver.net/main_5172227/5...
# 1  http://shopping.phinf.naver.net/main_5314890/5...
#
#                                            thumbnail sizeheight sizewidth
# 0  https://search.pstatic.net/common/?type=b150&s...        800       800
# 1  https://search.pstatic.net/common/?type=b150&s...       1000      1000

# %%
def save_img(attr, idx, query, url):
    import requests
    '{attr}_{idx}_{query}.{확장자} 이미지 저장'
    file_extension = url.split('.')[-1]
    quote_index = file_extension.find('?')
    
    if quote_index != -1:
        file_extension = file_extension[:quote_index]
    #print(file_extension)
    img = requests.get(url).content
    open(f'ch14_image/{attr}_{idx}_{query}.{file_extension}', 'wb').write(img)

# %%
save_img('메인',1,'청바지',df.loc[5,'link'])

# %%
def get_naver_image(word):
    import requests
    from dotenv import load_dotenv
    import os
    load_dotenv()
    client_id = os.getenv('Client_ID')
    client_secret = os.getenv('Client_Secret')
    url = f'https://openapi.naver.com/v1/search/image?query={word}&display=100'    
    headers = {
        'X-Naver-Client-Id': client_id,
        'X-Naver-Client-Secret': client_secret
    }
    response = requests.get(url, headers=headers)
    items = json.loads(response.text)['items']
    items_list = []
    for idx, item in enumerate(items):
        items_list.append({
            'title': item.get('title'),
            'link' : item.get('link'),
            'thumbnail' : item.get('thumbnail'),
            'sizeheight' : item.get('sizeheight'),
            'sizewidth' : item.get('sizewidth')})
        save_img('메인', idx+1, word, item.get('link'))
        save_img('썸내일', idx+1, word, item.get('thumbnail'))   
        
        df = pd.DataFrame(items_list)
        df.to_csv(f'ch14_image/{word}.csv',index=False)

# %%
get_naver_image('청바지')

# %% [markdown]
# ## xml 파일
# - https://www.yna.co.kr/rss/sports.xml

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.kma.go.kr/repositary/xml/fct/mon/img/fct_mon1rss_108_20250529.xml'
response = urlopen(url)
soup = BeautifulSoup(response,'xml')
locals = soup.find_all('local_ta')
items_list=[]
for local in locals:
    local_ta_name = local.select_one('local_ta_name')
    week1_normalYear = local.select_one('week1_local_ta_normalYear')
    week1_similarRange = local.select_one('week1_local_ta_similarRange')
    week1_min = local.select_one('week1_local_ta_minVal')
    week1_max = local.select_one('week1_local_ta_maxVal')
    week2_normalYear = local.select_one('week2_local_ta_normalYear')
    week2_similarRange = local.select_one('week2_local_ta_similarRange')
    week2_min = local.select_one('week2_local_ta_minVal')
    week2_max = local.select_one('week2_local_ta_maxVal')
    items_list.append({
        '지역':local_ta_name,
        '1주평년기온':week1_normalYear,
        '1주범위':week1_similarRange,
        '1주최저':week1_min,
        '1주최대':week1_max,
        '2주평년기온':week2_normalYear,
        '2주범위':week2_similarRange,
        '2주최저':week2_min,
        '2주최대':week2_max
    })
pd.DataFrame(items_list)
# Out:
#                   지역  1주평년기온         1주범위  1주최저  1주최대  2주평년기온         2주범위  \
# 0   [ 전국(제주도,북한제외) ]  [21.1]  [20.6~21.6]  [10]  [60]  [21.9]  [21.5~22.3]
# 1      [ 서울ㆍ인천ㆍ경기도 ]  [21.6]  [21.1~22.1]  [10]  [60]  [22.4]  [22.0~22.8]
# 2         [ 강원도 영서 ]  [20.3]  [19.7~20.9]  [10]  [60]  [21.3]  [20.7~21.9]
# 3         [ 강원도 영동 ]  [19.1]  [18.2~20.0]  [10]  [60]  [20.1]  [19.4~20.8]
# 4     [ 대전ㆍ세종ㆍ충청남도 ]  [21.5]  [21.0~22.0]  [10]  [60]  [22.3]  [21.9~22.7]
# 5           [ 충청북도 ]  [21.3]  [20.7~21.9]  [10]  [60]  [22.2]  [21.8~22.6]
# 6        [ 광주ㆍ전라남도 ]  [21.3]  [20.9~21.7]  [10]  [60]  [22.0]  [21.7~22.3]
# 7          [ 전북자치도 ]  [21.3]  [20.9~21.7]  [10]  [60]  [22.1]  [21.7~22.5]
# 8     [ 부산ㆍ울산ㆍ경상남도 ]  [21.3]  [20.8~21.8]  [10]  [60]  [22.1]  [21.7~22.5]
# 9        [ 대구ㆍ경상북도 ]  [20.9]  [20.3~21.5]  [10]  [60]  [21.9]  [21.3~22.5]
# 10           [ 제주도 ]  [21.0]  [20.6~21.4]  [10]  [60]  [21.6]  [21.2~22.0]
# ...

# %% [markdown]
# # 연습문제
# - 책 베스트셀러 정보를 csv.로 출력
# - 순위, 책이름, 저자, 출판사, 가격 (1~48)위 => 리스트 => 데이터프레임 => csv

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.yes24.com/product/category/bestseller?categoryNumber=001'
yes24 = requests.get(url)
yes24
# Out:
# <Response [200]>

# %%
yes24 = requests.get(url, headers=headers)
soup = BeautifulSoup(yes24.text, 
                    'html.parser')
soup
# Out:
# <!DOCTYPE html >
#
# <html lang="ko">
# <head><link <meta="" content="IE=Edge" href="https://m.yes24.com/Home/Best?DispNo=001" http-equiv="X-UA-Compatible" media="only screen and(max-width: 640px)" rel="alternate"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title> 국내도서 종합 베스트 - 예스24 </title>
# <meta content="예스24" name="title"/>
# <meta content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" name="keywords"/>
# ...

# %%
# 방법2
pages = 2
bestseller_list = []
with open('data/ch14_yes24.txt', 'w', encoding='utf-8') as f:
    pass
for page in range(1, pages+1):
    url = f'https://www.yes24.com/product/category/bestseller?pageNumber={page}'
    # print(url)
    response = urlopen(url)
    #print(response.status)
    soup = BeautifulSoup(response, 'html.parser')
    ranks_els = soup.select('div.img_upper > em.ico.rank')
    ranks = [int(ranks_el.text) for ranks_el in ranks_els]
    titles_els=soup.select("div.item_info > div.info_row > a.gd_name")
    titles = [titles_el.text for titles_el in titles_els]
    writers_els = soup.select("span.authPub.info_auth")
    # writers_els = soup.find_all('span', class_='info_auth')
    writers = [writers_el.text.strip() for writers_el in writers_els]
    publishers_els = soup.select('div.info_row.info_pubGrp > span.authPub.info_pub')
    publishers = [publishers_el.text for publishers_el in publishers_els]
    prices_els = soup.select("div.info_row > strong.txt_num")
    prices = [prices_el.text for prices_el in prices_els]
    # print(len(ranks), len(titles), len(writers), len(publishers), len(prices))
    with open('data/ch14_yes24.txt', 'a', encoding='utf-8') as f:
        for rank, title, writer, publisher, price in zip(ranks, titles, writers, publishers, prices):
            # print("{},{},{},{},{}".format(rank, title, writer, publisher, price))
            bestseller_list.append({
                'rank':rank, 
                'title':title,
                'writer':writer,
                'publisher':publisher,
                'price':price})
            f.write(f'{rank}, {title}, {writer}, {publisher}, {price}\n')
df = pd.DataFrame(bestseller_list)
df.to_csv('data/ch14_yes24.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       7 url = f'https://www.yes24.com/product/category/bestseller?pageNumber={page}'
#       8 # print(url)
# ----> 9 response = urlopen(url)
#      10 #print(response.status)
#      11 soup = BeautifulSoup(response, 'html.parser')
#
# NameError: name 'urlopen' is not defined

# %% [markdown]
# ## 버스 노선

# %%
# step 1 : 버스번호 -> busRouteId
# 노선정보조회 서비스3번 getBusRouteList 서비스

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve # url 경로파일을 내 pc에 저장
busNum = '511'
key = os.getenv('key')



url1 = f'http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?ServiceKey={key}&strSrch={busNum}'
print(url1)
savefilename = 'data/ch14_busInfo.xml'
urlretrieve(url1, savefilename)
xml = open(savefilename, 'r', encoding='utf-8').read()
soup = BeautifulSoup(xml, "xml")
#soup
for item in soup.select('itemList'):
    busRouteNm = item.select_one('busRouteNm').text
    if busRouteNm == busNum:
        busRouteId = item.select_one('busRouteId').text
        break
print('busRouteId:', busRouteId)
# Out:
# http://ws.bus.go.kr/api/rest/busRouteInfo/getBusRouteList?ServiceKey=ZS3iEVZ82iG9dvZc3urYq03YK9x0dwPWsaXcaNd1XACv8yWys1TONILRRSHiRNyrFo1qVk379RdHIUhAtRaL5w%3D%3D&strSrch=511
# busRouteId: 100100034

# %%
# step 2: busRouteId 로 버스 정류장 목록(정류장 이름과 정류장 id)
# 노선정보조회 서비스

# %%
import pandas as pd
url2 = f'http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey={key}&busRouteId={busRouteId}'
print(url2)
response = requests.get(url2)
soup = BeautifulSoup(response.text, "xml")
itemLists = soup.find_all('itemList')
print(busNum, '번 정류장 갯수 :', len(itemLists))
bus_station = []
for itemList in itemLists:
    stationNm = itemList.find('stationNm').text
    station = itemList.find('station').text
    gpsX = itemList.find('gpsX').text
    gpsY = itemList.find('gpsY').text
    bus_station.append([stationNm, station, gpsX, gpsY])
df = pd.DataFrame(bus_station, columns=['정류소명', 'id', '경도', '위도'])
df.head()
# Out:
# http://ws.bus.go.kr/api/rest/busRouteInfo/getStaionByRoute?ServiceKey=ZS3iEVZ82iG9dvZc3urYq03YK9x0dwPWsaXcaNd1XACv8yWys1TONILRRSHiRNyrFo1qVk379RdHIUhAtRaL5w%3D%3D&busRouteId=100100034
# 511 번 정류장 갯수 : 77
#              정류소명         id              경도             위도
# 0         정릉산장아파트  107000071      127.003343      37.616712
# 1    정릉4동주민센터.경국사  107000073      127.006345      37.613529
# 2     북한산보국문역2번출구  107000518  127.0079858233   37.612293899
# 3  성북청수도서관.정릉4동성당  107000075  127.0084193769  37.6115696748
# 4          정릉시장입구  107000077  127.0098212542  37.6084653256

# %%
url3 = f'http://ws.bus.go.kr/api/rest/buspos/getBusPosByRtid?ServiceKey={key}&busRouteId={busRouteId}'
print(url3)
response = requests.get(url3)
soup = BeautifulSoup(response.text, "xml")
bus_position = []
itemLists=soup.select('itemList')
for itemList in itemLists:
    # 차량번호, 혼잡도, 경도, 위도, 최종정류장id(lastStnId), 다음 정류장 id, 도착소요시간
    plainNo = itemList.select_one('plainNo').text
    congetion = itemList.select_one('congetion').text
    congetion = '여유' if congetion == '3' else ('보통' if congetion=='4'\
                                               else ('혼잡' if congetion == '5'\
                                                     else '매우혼잡'))
    gpsX = itemList.select_one('gpsX').text
    gpsY = itemList.select_one('gpsY').text
    lastStnId = itemList.select_one('lastStnId').text
    nextStId  = itemList.select_one('nextStId').text 
    nextStTm  = itemList.select_one('nextStTm').text
    bus_position.append({
        '차량혼잡도':plainNo,
        '혼잡도':congetion,
        '경도':gpsX,
        '위도':gpsY,
        '최종정류소id':lastStnId,
        '다음정류소id':nextStId,
        '도착소요시간':nextStTm
    })
df_pos = pd.DataFrame(bus_position)
df_pos.head(1)
# Out:
# http://ws.bus.go.kr/api/rest/buspos/getBusPosByRtid?ServiceKey=ZS3iEVZ82iG9dvZc3urYq03YK9x0dwPWsaXcaNd1XACv8yWys1TONILRRSHiRNyrFo1qVk379RdHIUhAtRaL5w%3D%3D&busRouteId=100100034
#        차량혼잡도   혼잡도          경도         위도    최종정류소id    다음정류소id 도착소요시간
# 0  서울74사1967  매우혼잡  127.003343  37.616712  107000071  107000079    383

# %%
# step3 : busRouteId로 버스 위치 정보 조회
df.loc[df['id'] == '107000079', '정류소명'].iloc[0]
# Out:
# '정릉우체국앞'

# %%
def station_name(row):
    row['최종정류소명'] = df.loc[df['id'] == row['최종정류소id'], '정류소명'].iloc[0]
    row['다음정류소명'] = df.loc[df['id'] == row['다음정류소id'], '정류소명'].iloc[0]
    return row

# %%
df_pos = df_pos.apply(station_name, axis=1)
df_pos
# Out:
#         차량혼잡도   혼잡도          경도         위도    최종정류소id    다음정류소id 도착소요시간  \
# 0   서울74사1967  매우혼잡  127.003343  37.616712  107000071  107000079    383
# 1   서울70사6556    여유  127.014298  37.601481  107000168  101000042   1733
# 2   서울74사3008    여유    127.0149  37.592374  107000174  101000042   1399
# 3   서울74사1537    여유  126.986984  37.577272  100000076  101000042    620
# 4   서울74사1618    여유  126.982632  37.567852  101000141  101000042    123
# 5   서울74사3372    여유  126.972779  37.554163  101000004  102000018    507
# 6   서울70사6557    여유   126.97053  37.541613  102000018  118000061    837
# 7   서울74사3366    여유   126.93449  37.520977  118000061  118000070   1206
# 8   서울74사1604    여유  126.924895  37.521159  118000071  118000070    914
# 9   서울70사6549    여유  126.923024  37.523023  118000071  118000070    897
# 10  서울74사2296    여유   126.92492  37.520614  118000070  102000053    628
# 11  서울74사2220    여유  126.968857  37.540027  102000046  102000019    228
# ...

# %%
# 컬럼명에 id 가 포함된 컬럼 삭제하기
drop_true = df_pos.columns.str.contains('id')
drop_column_name = df_pos.columns[drop_true]
df_pos.drop(drop_column_name, axis=1)
# Out:
#         차량혼잡도   혼잡도          경도         위도 도착소요시간       최종정류소명  \
# 0   서울74사1967  매우혼잡  127.003343  37.616712    383      정릉산장아파트
# 1   서울70사6556    여유  127.014298  37.601481   1733     정릉입구.정릉역
# 2   서울74사3008    여유    127.0149  37.592374   1399      성신여대입구역
# 3   서울74사1537    여유  126.986984  37.577272    620  창덕궁.우리소리박물관
# 4   서울74사1618    여유  126.982632  37.567852    123    을지로입구역.광교
# 5   서울74사3372    여유  126.972779  37.554163    507    서울역버스환승센터
# 6   서울70사6557    여유   126.97053  37.541613    837          남영역
# 7   서울74사3366    여유   126.93449  37.520977   1206  시범아파트.대교아파트
# 8   서울74사1604    여유  126.924895  37.521159    914     여의도역5번출구
# 9   서울70사6549    여유  126.923024  37.523023    897     여의도역5번출구
# 10  서울74사2296    여유   126.92492  37.520614    628     여의도역6번출구
# 11  서울74사2220    여유  126.968857  37.540027    228        용산경찰서
# 12  서울74사8118    여유  126.970376  37.541299    280        용산경찰서
# 13  서울70사6554    여유  126.972155  37.550821    112          갈월동
# ...
