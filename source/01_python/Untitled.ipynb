# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:15pt;}
div.output {font-size:15pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:15pt;}
div.prompt {min-width:70px;
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:15px;}
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:15pt;}
# div.output {font-size:15pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:15pt;}
# div.prompt {min-width:70px;
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:15px;}
# </style>

# %%
import pandas as pd


# In[244]:


location_rain = pd.read_csv(r'C:\Users\Admin\Desktop\21 ~ 24 지역구 기상 데이터\프로젝트\row data\25\강남구\신사동_강수_202501_202505.csv', encoding='cp949')
location_rain.columns = ['날(일)', '시간', '강수']

# 22년 월별분리
month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]  # 2022 각 월별 일수
rows_per_month = [days * 24 for days in month_days]
month_column = []
for month, count in enumerate(rows_per_month, start=1):
    month_column.extend([month] * count)
len(month_column), location_rain.shape[0]
difference = len(location_rain) - len(month_column)
month_column += [12] * difference
location_rain['월'] = month_column
   
# 열순서 수정

location_rain = location_rain[['월', '날(일)', '시간', '강수']]
   
# 시간 단위 수정
location_rain['시간'] = pd.to_numeric(location_rain['시간'], errors='coerce') // 100


# In[245]:


location_temp = pd.read_csv(r'C:\Users\Admin\Desktop\21 ~ 24 지역구 기상 데이터\프로젝트\row data\25\강남구\신사동_기온_202501_202505.csv', encoding='cp949')
location_temp.columns = ['날(일)', '시간', '기온']

# 22년 월별분리
month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]  # 2022 각 월별 일수
rows_per_month = [days * 24 for days in month_days]
month_column = []
for month, count in enumerate(rows_per_month, start=1):
    month_column.extend([month] * count)
len(month_column), location_temp.shape[0]
difference = len(location_temp) - len(month_column)
month_column += [12] * difference
location_temp['월'] = month_column
   
# 열순서 수정

location_temp = location_temp[['월', '날(일)', '시간', '기온']]
   
# 시간 단위 수정
location_temp['시간'] = pd.to_numeric(location_temp['시간'], errors='coerce') // 100


# In[246]:


location_hum = pd.read_csv(r'C:\Users\Admin\Desktop\21 ~ 24 지역구 기상 데이터\프로젝트\row data\25\강남구\신사동_습도_202501_202505.csv.csv', encoding='cp949')
location_hum.columns = ['날(일)', '시간', '습도']

# 22년 월별분리
month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]  # 2022 각 월별 일수
rows_per_month = [days * 24 for days in month_days]
month_column = []
for month, count in enumerate(rows_per_month, start=1):
    month_column.extend([month] * count)
len(month_column), location_temp.shape[0]
difference = len(location_hum) - len(month_column)
month_column += [12] * difference
location_hum['월'] = month_column
   
# 열순서 수정

location_hum = location_hum[['월', '날(일)', '시간', '습도']]
   
# 시간 단위 수정
location_hum['시간'] = pd.to_numeric(location_hum['시간'], errors='coerce') // 100


# In[247]:


location_wind = pd.read_csv(r'C:\Users\Admin\Desktop\21 ~ 24 지역구 기상 데이터\프로젝트\row data\25\강남구\신사동_풍속_202501_202505.csv.csv', encoding='cp949')
location_wind.columns = ['날(일)', '시간', '풍속']

# 22년 월별분리
month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]  # 2022년은 윤년 아님
rows_per_month = [days * 24 for days in month_days]
month_column = []
for month, count in enumerate(rows_per_month, start=1):
    month_column.extend([month] * count)
len(month_column), location_wind.shape[0]
difference = len(location_wind) - len(month_column)
month_column += [12] * difference
location_wind['월'] = month_column
   
# 열순서 수정

location_wind = location_wind[['월', '날(일)', '시간', '풍속']]
   
# 시간 단위 수정
location_wind['시간'] = pd.to_numeric(location_wind['시간'], errors='coerce') // 100


# 수정csv 파일 정리
#location_wind.to_csv('청운효자동_습도_정리본.csv', index=False, encoding='utf-8-sig')
#location_wind.to_csv(r'C:\Users\du596\Desktop\프로젝트\청운효자동_습도_정리본.csv', index=False, encoding='utf-8-sig')


# In[248]:


location_rain.shape, location_temp.shape, location_hum.shape, location_wind.shape


# In[249]:


location_merged_df = pd.concat([
    location_rain,
    location_temp.iloc[:, 3],  
    location_hum.iloc[:, 3],
    location_wind.iloc[:, 3]
], axis=1)


# In[250]:


location_merged_df


# In[251]:


location_merged_df_cut = location_merged_df.head(3629)


# In[252]:


location_merged_df_cut.shape


# In[253]:


location_merged_df_cut.to_csv(r'C:\Users\Admin\Desktop\21 ~ 24 지역구 기상 데이터\프로젝트\25년도\25강남구_일기_정리본.csv', index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 19
#      17 difference = len(location_rain) - len(month_column)
#      18 month_column += [12] * difference
# ---> 19 location_rain['월'] = month_column
#      21 # 열순서 수정
#      23 location_rain = location_rain[['월', '날(일)', '시간', '강수']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
#    3977     self._setitem_array([key], value)
#    3978 else:
#    3979     # set column
# -> 3980     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
#    4164 def _set_item(self, key, value) -> None:
#    4165     """
#    4166     Add series to DataFrame in specified column.
#    4167
#    (...)
#    4172     ensure homogeneity.
#    4173     """
# -> 4174     value = self._sanitize_column(value)
#    4176     if (
#    4177         key in self.columns
#    4178         and value.ndim == 1
#    4179         and not is_extension_array_dtype(value)
#    4180     ):
#    4181         # broadcast across multiple columns if necessary
#    4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
#     567 """
#     568 Check the length of data matches the length of the index.
#     569 """
#     570 if len(data) != len(index):
# --> 571     raise ValueError(
#     572         "Length of values "
#     573         f"({len(data)}) "
#     574         "does not match length of index "
#     575         f"({len(index)})"
#     576     )
#
# ValueError: Length of values (8760) does not match length of index (3628)
